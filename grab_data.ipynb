# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

import warnings

# %%
movies = {'Everything Everywhere All at Once':"https://www.rottentomatoes.com/m/everything_everywhere_all_at_once/reviews",
          'CODA':"https://www.rottentomatoes.com/m/coda_2021/reviews"}

# %%
# Iterate through the movie URLs
for movie, url in movies.items():
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the section containing the critic reviews
        critic_reviews_section = soup.find('div', class_='layout reviews-page-container')

        # Check if the critic reviews section exists
        if critic_reviews_section:
            # Find all the critic reviews
            critic_reviews = critic_reviews_section.find_all('div', class_="review-row")

            # Print the critic reviews for the movie
            print(f"Reviews for {movie}:\n")
            for review in critic_reviews:
                critic_name = review.find('a', class_='display-name').text.strip()
                critic_rating = review.find('score-icon-critic-deprecated').get('state')
                critic_text = review.find('p', class_='review-text').text.strip()
                critic_date = review.find('span', attrs={'data-qa':'review-date'}).text.strip()

                print(f"Critic: {critic_name}")
                print(f"Rating: {critic_rating}")
                print(f"Review: {critic_text}\n")
                print(f"Date: {critic_date}\n")
        else:
            print(f"No critic reviews found for {movie}.\n")

    else:
        print(f"Failed to retrieve data for {movie}. Status code: {response.status_code}\n")
# Out:
# Reviews for Everything Everywhere All at Once:
#
# Critic: Christian Eulinberg
# Rating: fresh
# Review: The Daniels accomplished something wonderful for the audience.
#
# Date: Sep 26, 2023
#
# Critic: Gautam Sunder
# Rating: fresh
# Review: Michelle Yeoh finally gets a role this decade that pays tribute to her rare talents, and absolutely owns it...
#
# Date: Sep 12, 2023
#
# Critic: Sarah Vincent
# Rating: fresh
# Review: The genre mashup provides a fuller insight into the characters’ personalities than a straight independent film could depict. The multiverse is a metaphor for the different facets of peoples’ potential and makes their internal lives literal.
#
# Date: Aug 16, 2023
#
# Critic: Emma-Jane Betts
# Rating: fresh
# Review: Everything Everywhere All at Once will remind you of why you love cinema. It is fresh, creative, and will leave you laughing and shedding some tears.
#
# Date: Jul 27, 2023
#
# Critic: Paul Kanieski
# Rating: fresh
# Review: An omnipotent being is threatening the multiverse. Who ya gonna call? Spiderman? Dr. Strange? How about a middle-aged Asian-American woman failing as a wife and mother?
#
# Date: Jul 26, 2023
#
# Critic: Zach Pope
# Rating: fresh
# Review: Everything Everywhere All at Once is one of the greatest films of all time. Entertaining, hilarious, emotional, wild, unique, action packed, & INSANE
#
# Date: Jul 25, 2023
#
# Critic: Matthew Creith
# Rating: fresh
# Review: At the heart of it all, we ride a roller coaster of emotions that are inventive, complex, stimulating, and raw.
#
# Date: Jul 25, 2023
#
# Critic: Manuel São Bento
# Rating: fresh
# Review: With such a low budget, it's almost humiliating that so many expensive Hollywood blockbusters can't even reach the heels of so much originality, imagination, excitement, and emotion.
#
# Date: Jul 25, 2023
#
# Critic: Tina Kakadelis
# Rating: fresh
# Review: Everything Everywhere All At Once is a spectacle in the purest sense of the word. A sensory overload, especially in IMAX, the movie is a science fiction, multi-verse spanning love letter to family.
#
# Date: Jul 25, 2023
#
# Critic: Isabel Ong
# Rating: fresh
# Review: Delightfully disorienting and intellectually absorbing.
#
# Date: May 26, 2023
#
# Critic: Cole Smithey
# Rating: rotten
# Review: "Everything Everywhere All At Once" is a steaming example of visual, sonic, and thematic noise. Chinese propaganda for propaganda's sake. Vomiting all of the time now. Hollywood pawns.
#
# Date: May 11, 2023
#
# Critic: Greg Carlson
# Rating: fresh
# Review: At a few minutes short of two and a half hours, Everything Everywhere All at Once nearly wears out its welcome, but as far as hot dog-fingered audacity goes, the Daniels will make plenty of new eyeballs go googly.
#
# Date: May 9, 2023
#
# Critic: Juan José Beteta
# Rating: fresh
# Review: ... Touches upon important themes such as control through technology, media, food, and body while resorting to an anarchic and hilarious sense of humor. [Full review in Spanish]
#
# Date: Mar 28, 2023
#
# Critic: Eve Tushnet
# Rating: rotten
# Review: The filmmakers try to load the entire weight of life, the universe, and everything onto their movie. This is too many things on a bagel.
#
# Date: Mar 24, 2023
#
# Critic: Carla Renata
# Rating: fresh
# Review: Michelle Yeoh proves that being a middle aged immigrant has no boundaries and she is backed up with the amazingly gifted talents of Ke Huy Quan, Jaime Lee Curtis and Stephanie Hsu !  The Daniels provide a supreme sci-fi smorgasbord for the ages.
#
# Date: Mar 22, 2023
#
# Critic: Milana Vujkov
# Rating: rotten
# Review: It holds within it a great idea, when one disentangles it from the hairball that is the EEAAO narrative. But [...] in all its originality, it telegraphs its message, instead of allowing this intricately constructed ingenious world to be the message.
#
# Date: Mar 19, 2023
#
# Critic: Robin Holabird
# Rating: fresh
# Review: Outrageous, confusing or confounding, Everything Everywhere All At Once stands out as one of the most original movies to come along in years.
#
# Date: Mar 16, 2023
#
# Critic: A.S. Hamrah
# Rating: rotten
# Review: The humor, though, is silly and second-rate. The googly eyes, the talking raccoon, the pet rocks at sunset, the parody of 2001: A Space Odyssey—all those work against the cast instead of with it.
#
# Date: Mar 16, 2023
#
# Critic: Eric Webb
# Rating: fresh
# Review: Much like a hallucinogen might cause you to cycle through every human emotion and see your life laid out end to end — theoretically — this film has an ability to dazzle built into every kinetic, colorful, madcap frame.
#
# Date: Mar 16, 2023
#
# Critic: Carlos Boyero
# Rating: rotten
# Review: ... This victorious though regrettable film, or whatever it is, is an incomprehensible mess, foolishly imaginative and cumbersome to watch and listen to. [Full review in Spanish]
#
# Date: Mar 15, 2023
#
# Reviews for CODA:
#
# Critic: Nadine Whitney
# Rating: fresh
# Review: CODA is a delight, a warm hug of a film that knows its genre and makes the very most of it. Siân Heder’s script is simple, and the message that she sends is heartfelt. A crowd-pleaser with love to spare.
#
# Date: Sep 17, 2023
#
# Critic: Mo Muzammal
# Rating: rotten
# Review: ...weakening a film whose representation of the underrepresented is so intense at times that its dependence on Hallmark-like characteristics is more than mildly disappointing.
#
# Date: Jul 27, 2023
#
# Critic: Zach Pope
# Rating: fresh
# Review: A Must Watch Winner that will delight you
#
# Date: Jul 26, 2023
#
# Critic: Manuel São Bento
# Rating: fresh
# Review: Siân Heder offers her impeccable direction and beautifully written screenplay, which is packed with emotionally powerful moments that left me tearing up for the last forty-five minutes.
#
# Date: Jul 24, 2023
#
# Critic: Mark Johnson
# Rating: fresh
# Review: CODA is a simple, moving film with great performances.
#
# Date: Jun 27, 2023
#
# Critic: Connie Guglielmo
# Rating: fresh
# Review: What so impressed me and makes this a movie I'd recommend is how writer and director Sian Heder used sound -- and the lack of sound -- to showcase the beauty and emotional power of music to connect with people.
#
# Date: Mar 31, 2023
#
# Critic: Benjamin Wiebe
# Rating: fresh
# Review: With one of the most clever scripts of the year, CODA made me feel a lot of feelings.
#
# Date: Feb 10, 2023
#
# Critic: Cate Young
# Rating: fresh
# Review: "CODA is sweet, sincere and genuinely funny in parts, and it’s precisely the kind of coming-of-age film that we should hope to see more of. "
#
# Date: Nov 19, 2022
#
# Critic: Josh Larsen
# Rating: fresh
# Review: ...alternates between being contrived and genuinely moving.
#
# Date: Oct 9, 2022
#
# Critic: M.N. Miller
# Rating: fresh
# Review: CODA is cathartic. A film that put a giant lump in your throat while at the same time lifting your spirits.
#
# Date: Oct 9, 2022
#
# Critic: Rob Gonsalves
# Rating: fresh
# Review: It’s a movie about a cute kid who wants to go off to Fancy School in the City. The deafness is very much incidental.
#
# Date: Aug 24, 2022
#
# Critic: Keith Garlington
# Rating: fresh
# Review: The humor makes for a great compliment to the coming-of-age drama which follows a pretty conventional blueprint but enhances it with a uniquely fresh perspective.
#
# Date: Aug 17, 2022
#
# Critic: DarkSkyLady
# Rating: fresh
# Review: Films like these highlight the differences and similarities and seek the bridge that gap as well as share a story of struggle, growth, and exploration. This film does all three magnificently and will bring audiences to tears.
#
# Date: Aug 14, 2022
#
# Critic: Cris Kennedy
# Rating: fresh
# Review: ... The bones of The Belier Family are fleshed out in new, muscular ways by writer-director Sian Heder, working with deaf creative collaborators Anne Tomasetti and Alexandria Wailes.
#
# Date: Aug 4, 2022
#
# Critic: Tatat Bunnag
# Rating: fresh
# Review: CODA works well to deliver effective drama, music and some comedy with character conflicts that are relatable.
#
# Date: Jul 1, 2022
#
# Critic: Carlos Boyero
# Rating: fresh
# Review: A foreseeable story that's adamant to be kind and only threat is sweetening the characters and the situations they go through, and makes it clear that the ending, too, will be conveniently happy. [Full review in Spanish]
#
# Date: Jun 8, 2022
#
# Critic: Luis Martínez
# Rating: rotten
# Review: What hurts the most is the almost algorithmic…mechanisms of tabletop drama.
# [Full review in Spanish]
#
# Date: May 12, 2022
#
# Critic: Joe Lipsett
# Rating: fresh
# Review: A feel good triumph and standard coming of age narrative. The opportunities afforded the deaf cast are cause for celebration, even if their stories would have been more exciting to see compared to the familiar YA romance of the hearing protagonist
#
# Date: Apr 25, 2022
#
# Critic: Chris McCoy
# Rating: fresh
# Review: CODA is a classic story of intergenerational conflict spiced up with a culture clash narrative between the deaf and hearing communities. The execution is nearly flawless
#
# Date: Apr 13, 2022
#
# Critic: Don Shanahan
# Rating: fresh
# Review: Heart sometimes beats prestige and we couldn't be more OK with that.
#
# Date: Apr 9, 2022
